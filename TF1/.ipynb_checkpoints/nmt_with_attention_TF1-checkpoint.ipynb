# %% [markdown]
# # Neural Machine Translation with Attention
#
# This notebook trains a sequence to sequence (seq2seq) model for Spanish to English translation. This is an advanced example that assumes some knowledge of sequence to sequence models.
#
# After training the model in this notebook, you will be able to input a Spanish sentence, such as *"¿todavia estan en casa?"*, and return the English translation: *"are you still at home?"*
#
# The translation quality is reasonable for a toy example, but the generated attention plot is perhaps more interesting. This shows which parts of the input sentence has the model's attention while translating:
#
# <img src="https://tensorflow.org/images/spanish-english.png" alt="spanish-english attention plot">
#
# Note: This example takes approximately 10 mintues to run on a single P100 GPU.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# !pip install tensorflow-gpu==1.13.1
import tensorflow as tf
tf.enable_eager_execution()

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time
# Out:
# Requirement already satisfied: tensorflow-gpu==1.13.1 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (1.13.1)
# Requirement already satisfied: absl-py>=0.1.6 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (0.7.1)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.13.1)
# Requirement already satisfied: six>=1.10.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.12.0)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.13.0)
# Requirement already satisfied: gast>=0.2.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (0.2.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.0.7)
# Requirement already satisfied: astor>=0.6.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (0.7.1)
# Requirement already satisfied: protobuf>=3.6.1 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (3.7.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.16.2)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (0.33.1)
# Requirement already satisfied: grpcio>=1.8.6 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.19.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1) (1.0.9)
# Requirement already satisfied: markdown>=2.6.8 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (0.15.2)
# Requirement already satisfied: mock>=2.0.0 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (2.0.0)
# Requirement already satisfied: h5py in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (2.9.0)
# Requirement already satisfied: setuptools in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow-gpu==1.13.1) (41.0.0)
# Requirement already satisfied: pbr>=0.11 in /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (5.1.3)

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/. This dataset contains language translation pairs in the format:
#
# ```
# May I borrow this book?	¿Puedo tomar prestado este libro?
# ```
#
# There are a variety of languages available, but we'll use the English-Spanish dataset. For convenience, we've hosted a copy of this dataset on Google Cloud, but you can also download your own copy. After downloading the dataset, here are the steps we'll take to prepare the data:
#
# 1. Add a *start* and *end* token to each sentence.
# 2. Clean the sentences by removing special characters.
# 3. Create a word index and reverse word index (dictionaries mapping from word → id and id → word).
# 4. Pad each sentence to a maximum length.

# %%
# Download the file
path_to_zip = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

path_to_file = os.path.dirname(path_to_zip)+"/spa-eng/spa.txt"

import requests
if not os.path.exists("./kor-eng/kor.txt"):
  with open("kor-eng.zip", "wb") as f:
    f.write(requests.get("https://www.manythings.org/anki/kor-eng.zip", headers={'User-Agent': "Magic Browser"}).content)
  with zipfile.ZipFile("kor-eng.zip") as f:
    f.extractall("./kor-eng/")
path_to_file_ko = "./kor-eng/kor.txt"

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",", 한글)
    w = re.compile(r'[^a-zA-Z?.!,¿ ㄱ-ㅣ가-힣]+').sub("", w)

    w = unicode_to_ascii(w.lower().strip())

    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)

    w = w.rstrip().strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
en_sentence = u"May I borrow this book?"
sp_sentence = u"¿Puedo tomar prestado este libro?"
ko_sentence = u"이 책을 貸與(대여) 해도 될까요?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(sp_sentence))
print(preprocess_sentence(ko_sentence))
# Out:
# <start> may i borrow this book ? <end>
# <start> ¿ puedo tomar prestado este libro ? <end>
# <start> 이 책을 대여 해도 될까요 ? <end>

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]
def create_dataset(path, num_examples):
    lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

    word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

    return zip(*word_pairs)

# %%
en, sp = create_dataset(path_to_file, None)
print(en[-1])
print(sp[-1])

en2, ko = create_dataset(path_to_file_ko, None)
for e, k in zip(en2, ko):
  print(e, k)
# Out:
# <start> if you want to sound like a native speaker , you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo . <end>
# <start> si quieres sonar como un hablante nativo , debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un msico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado . <end>
# <start> who ? <end> <start> 누구 ? <end>
# <start> hello ! <end> <start> 안녕 ! <end>
# <start> no way ! <end> <start> 절대 아니야 . <end>
# <start> no way ! <end> <start> 그럴리가 ! <end>
# <start> im sad . <end> <start> 슬퍼 . <end>
# <start> me , too . <end> <start> 나도 . <end>
# <start> perfect ! <end> <start> 완벽해 ! <end>
# <start> shut up ! <end> <start> 시끄러워 ! <end>
# <start> welcome . <end> <start> 어서오세요 . <end>
# <start> welcome . <end> <start> 환영합니다 . <end>
# <start> cheer up ! <end> <start> 힘내 ! <end>
# <start> get lost . <end> <start> 꺼져 . <end>
# <start> im ugly . <end> <start> 나는 못 생겼다 . <end>
# <start> it hurts . <end> <start> 아파 . <end>
# <start> lets go ! <end> <start> 가자 ! <end>
# <start> dont lie . <end> <start> 거짓말 하지 마 . <end>
# <start> dont lie . <end> <start> 거짓말 하지 마세요 . <end>
# <start> im sorry . <end> <start> 미안해 . <end>
# <start> im sorry . <end> <start> 미안해요 . <end>
# <start> im sorry . <end> <start> 죄송합니다 . <end>
# <start> im sorry . <end> <start> 유감입니다 . <end>
# <start> of course . <end> <start> 물론이죠 . <end>
# <start> seriously ? <end> <start> 진심이야 ? <end>
# <start> take care . <end> <start> 주의하세요 . <end>
# <start> be careful . <end> <start> 조심해 ! <end>
# <start> he is nice . <end> <start> 걔 괜찮아 . <end>
# <start> hold still . <end> <start> 가만히 있으세요 . <end>
# <start> hold still . <end> <start> 가만히 있어 . <end>
# <start> how lovely ! <end> <start> 어찌나 사랑스러운지 ! <end>
# <start> i felt bad . <end> <start> 난 기분이 나빴다 . <end>
# <start> is that ok ? <end> <start> 괜찮은 거예요 ? <end>
# <start> love hurts . <end> <start> 사랑은 아프다 . <end>
# <start> boys do cry . <end> <start> 남자애도 운다 . <end>
# <start> i dont lie . <end> <start> 나는 거짓말 하지 않습니다 . <end>
# <start> i dont lie . <end> <start> 난 거짓말 안해 . <end>
# <start> i dont lie . <end> <start> 나는 거짓말 하지 않아 . <end>
# <start> im nervous . <end> <start> 긴장돼요 . <end>
# <start> im nervous . <end> <start> 떨려요 . <end>
# <start> im shocked . <end> <start> 충격이야 . <end>
# <start> its a pity . <end> <start> 안타까워요 . <end>
# <start> whats that ? <end> <start> 저건 뭐야 ? <end>
# <start> youre mine . <end> <start> 넌 내 거야 . <end>
# <start> youre mine . <end> <start> 당신은 나의 것입니다 . <end>
# <start> blood is red . <end> <start> 피는 붉다 . <end>
# <start> come quickly ! <end> <start> 빨리 와 ! <end>
# <start> come quickly ! <end> <start> 빨리 오세요 ! <end>
# <start> dont eat it . <end> <start> 먹지 마 . <end>
# <start> i dont know . <end> <start> 나는 몰라요 . <end>
# <start> i hate liars . <end> <start> 난 거짓말쟁이가 싫어 . <end>
# <start> i need money . <end> <start> 돈이 필요해요 . <end>
# <start> is that okay ? <end> <start> 괜찮은 거예요 ? <end>
# <start> is this mine ? <end> <start> 이거 내꺼니 ? <end>
# <start> is this wine ? <end> <start> 이게 와인이야 ? <end>
# <start> its suicide . <end> <start> 자살입니다 . <end>
# <start> just keep it . <end> <start> 그냥 그거 가져 . <end>
# <start> we dont lie . <end> <start> 우리는 거짓말을 하지 않아요 . <end>
# <start> we dont lie . <end> <start> 우린 거짓말 안해 . <end>
# <start> were inside . <end> <start> 우리 안에 들어와 있어 . <end>
# <start> were inside . <end> <start> 우린 안에 있어요 . <end>
# <start> what is that ? <end> <start> 저것은 무엇입니까 ? <end>
# <start> can i ask why ? <end> <start> 이유를 물어봐도 돼 ? <end>
# <start> grab the rope . <end> <start> 로프를 잡으세요 . <end>
# <start> i am homesick . <end> <start> 나 향수병 걸렸어 . <end>
# <start> i cant sleep . <end> <start> 잠이 와 . <end>
# <start> i feel guilty . <end> <start> 죄책감이 들어 . <end>
# <start> i hate myself . <end> <start> 나는 내 자신이 싫어 . <end>
# <start> i smell blood . <end> <start> 피 냄새가 납니다 . <end>
# <start> i use firefox . <end> <start> 나는 파이어폭스를 사용해 . <end>
# <start> i want to die . <end> <start> 죽고 싶어요 . <end>
# <start> i want to die . <end> <start> 죽고 싶어 . <end>
# <start> ill kill him . <end> <start> 나는 그를 죽일 것이다 . <end>
# <start> im depressed . <end> <start> 우울해 . <end>
# <start> is that blood ? <end> <start> 그거 피야 ? <end>
# <start> my head hurts . <end> <start> 머리가 아파요 . <end>
# <start> we want peace . <end> <start> 우리는 평화를 원합니다 . <end>
# <start> autumn is here . <end> <start> 가을이 되었습니다 . <end>
# <start> autumn is here . <end> <start> 가을이 왔어요 . <end>
# <start> can i help you ? <end> <start> 제가 좀 도와 드릴까요 ? <end>
# <start> do you hear me ? <end> <start> 제 말이 들리세요 ? <end>
# <start> he was hard up . <end> <start> 그는 돈에 쪼들리고 있었다 . <end>
# <start> call this number . <end> <start> 이 번호로 전화해 . <end>
# <start> do you like fish ? <end> <start> 생선 좋아해요 ? <end>
# <start> do you like fish ? <end> <start> 생선 좋아해 ? <end>
# <start> do you like fish ? <end> <start> 물고기 좋아하나요 ? <end>
# <start> do you like fish ? <end> <start> 물고기 좋아해 ? <end>
# <start> drink some water . <end> <start> 물 좀 마셔 . <end>
# <start> he loves singing . <end> <start> 그는 노래하기를 좋아한다 . <end>
# <start> her hair is long . <end> <start> 그녀의 머리카락은 길어 . <end>
# <start> her hair is long . <end> <start> 그녀의 머리카락은 길다 . <end>
# <start> here is the bill . <end> <start> 여기 계산서 입니다 . <end>
# <start> i felt very safe . <end> <start> 나는 매우 안전하다고 느꼈다 . <end>
# <start> i like languages . <end> <start> 언어를 좋아합니다 . <end>
# <start> i like languages . <end> <start> 언어가 좋습니다 . <end>
# <start> i live in turkey . <end> <start> 터키에 살아요 . <end>
# <start> i lost my wallet . <end> <start> 지갑을 잃어버렸어 . <end>
# <start> i missed the bus . <end> <start> 버스를 놓쳤어요 . <end>
# <start> i said im sorry . <end> <start> 미안하다고 했잖아 . <end>
# <start> i said im sorry . <end> <start> 미안하다고 했잖아요 . <end>
# <start> im not suicidal . <end> <start> 나는 자살하고 싶지 않다 . <end>
# <start> is the bank open ? <end> <start> 은행 문 열었어요 ? <end>
# <start> is the bank open ? <end> <start> 은행 해요 ? <end>
# <start> there arent any . <end> <start> 없다 . <end>
# <start> theyre amateurs . <end> <start> 걔네 초짜야 . <end>
# <start> think about this . <end> <start> 생각 좀 해봐 . <end>
# <start> tom isnt skinny . <end> <start> 톰은 마르지 않았다 . <end>
# <start> water the plants . <end> <start> 식물에 물을 주세요 . <end>
# <start> we cant give up . <end> <start> 우린 포기할 수 없어 . <end>
# <start> we cant give up . <end> <start> 포기할 수 없어요 . <end>
# <start> what do you like ? <end> <start> 무엇을 좋아하세요 ? <end>
# <start> what do you like ? <end> <start> 뭘 좋아해 ? <end>
# <start> what do you like ? <end> <start> 뭐가 좋아 ? <end>
# <start> youll regret it . <end> <start> 너 후회할거야 . <end>
# <start> i believe in love . <end> <start> 난 사랑을 믿는다 . <end>
# <start> i have a headache . <end> <start> 머리가 아파요 . <end>
# <start> i was intoxicated . <end> <start> 술 취했었다 . <end>
# <start> i wont permit it . <end> <start> 나는 그것을 허락하지 않을거야 . <end>
# <start> im a simple girl . <end> <start> 저는 단순한 소녀에요 . <end>
# <start> im in charge now . <end> <start> 이제 내가 책임을 지고 있다 . <end>
# <start> its a dictionary . <end> <start> 이것은 사전이다 . <end>
# <start> leave me in peace ! <end> <start> 저를 내버려 두세요 ! <end>
# <start> look at the clock . <end> <start> 시계를 보세요 . <end>
# <start> may god bless you . <end> <start> 신께서 당신을 축복하시길 . <end>
# <start> nobody is perfect . <end> <start> 그 누구도 완벽하지 않는다 . <end>
# <start> she loves singing . <end> <start> 그녀는 노래하기를 좋아한다 . <end>
# <start> take the medicine . <end> <start> 그 약을 먹으세요 . <end>
# <start> theyre all liars . <end> <start> 너희 모두 거짓말쟁이다 . <end>
# <start> tom vomited blood . <end> <start> 톰은 피를 토했다 . <end>
# <start> tom won the match . <end> <start> 톰은 경기에서 이겼다 . <end>
# <start> turn on the radio . <end> <start> 라디오를 켜세요 . <end>
# <start> where is the bank ? <end> <start> 그 은행은 어디에 있어요 ? <end>
# <start> where is the bank ? <end> <start> 그 은행은 어디 있어 ? <end>
# <start> why are you lying ? <end> <start> 왜 거짓말 하는거야 ? <end>
# <start> you are beautiful . <end> <start> 아름다우시네요 . <end>
# <start> you can have mine . <end> <start> 너는 내 것을 가질 수 있다 . <end>
# <start> youre both liars . <end> <start> 너희 둘 다 거짓말쟁이다 . <end>
# <start> can i see this one ? <end> <start> 이것 좀 보여주실래요 ? <end>
# <start> dont get me wrong . <end> <start> 오해하지 마 . <end>
# <start> he kept me waiting . <end> <start> 그는 나를 기다리게 했다 . <end>
# <start> i didnt know that . <end> <start> 그건 몰랐어요 . <end>
# <start> i dont understand . <end> <start> 이해가 안돼 . <end>
# <start> i need to warn tom . <end> <start> 나는 톰에게 경고해야 해 . <end>
# <start> i really like snow . <end> <start> 나는 눈이 정말 좋아요 . <end>
# <start> i really like snow . <end> <start> 난 눈이 정말 좋아 . <end>
# <start> is that real blood ? <end> <start> 그거 진짜 피야 ? <end>
# <start> life is never easy . <end> <start> 사는게 쉽지가 않아 . <end>
# <start> she has small feet . <end> <start> 그녀는 발이 작다 . <end>
# <start> some water , please . <end> <start> 물 좀 주세요 , 제발 . <end>
# <start> the night was cold . <end> <start> 그날 밤은 추웠어 . <end>
# <start> tie your shoelaces . <end> <start> 신발끈을 묶으세요 . <end>
# <start> we were retreating . <end> <start> 우리는 후퇴하고 있었다 . <end>
# <start> weve been worried . <end> <start> 계속 걱정했어 . <end>
# <start> whose book is this ? <end> <start> 이것은 누구의 책입니까 ? <end>
# <start> do you like english ? <end> <start> 영어 좋아해요 ? <end>
# <start> do you like english ? <end> <start> 영어 좋아해 ? <end>
# <start> do you like cooking ? <end> <start> 요리 좋아해요 ? <end>
# <start> do you like cooking ? <end> <start> 요리 좋아해 ? <end>
# <start> do you like singing ? <end> <start> 노래하는 거 좋아해요 ? <end>
# <start> do you like singing ? <end> <start> 노래하는 거 좋아해 ? <end>
# <start> everybody loves her . <end> <start> 모두 그녀를 사랑한다 . <end>
# <start> everybody loves him . <end> <start> 모두가 그를 사랑한다 . <end>
# <start> how may i serve you ? <end> <start> 어떻게 도와드릴까요 ? <end>
# <start> i did nothing wrong . <end> <start> 난 잘못한 거 없어 . <end>
# <start> i do not fear death . <end> <start> 전 죽음이 두렵지 않습니다 . <end>
# <start> i do not fear death . <end> <start> 난 죽음이 두렵지 않다 . <end>
# <start> i dont know either . <end> <start> 나도 몰라 . <end>
# <start> i dont sleep a lot . <end> <start> 나는 잠이 많지 않아요 . <end>
# <start> i dont sleep a lot . <end> <start> 나는 많이 자지 않아요 . <end>
# <start> i dont sleep a lot . <end> <start> 나는 잠이 별로 없어 . <end>
# <start> i felt the same way . <end> <start> 동감이야 . <end>
# <start> i felt the same way . <end> <start> 동감이에요 . <end>
# <start> i have a dictionary . <end> <start> 나에게 사전이 있다 . <end>
# <start> i made reservations . <end> <start> 예약해 뒀어요 . <end>
# <start> i made reservations . <end> <start> 예약해 놨어 . <end>
# <start> ill never tell you . <end> <start> 나는 결코 너에게 말하지 않을 것이다 . <end>
# <start> ill take the wheel . <end> <start> 내가 운전할께 . <end>
# <start> im still in school . <end> <start> 저는 아직 학교에 다녀요 . <end>
# <start> im still in school . <end> <start> 나는 아직 학교에 다녀 . <end>
# <start> ive been kidnapped . <end> <start> 나 유괴 당한 적 있어 . <end>
# <start> ive seen you on tv . <end> <start> 티비에서 봤어요 . <end>
# <start> its not your fault . <end> <start> 네 탓은 아니야 . <end>
# <start> lets do this later . <end> <start> 이건 좀 이따 하자 . <end>
# <start> now ive had enough . <end> <start> 이제 충분히 했습니다 . <end>
# <start> please drive slowly . <end> <start> 천천히 운전하세요 . <end>
# <start> thats your funeral . <end> <start> 그건 네 책임이야 . <end>
# <start> this is so relaxing . <end> <start> 이거 정말 기분 좋다 . <end>
# <start> this is so relaxing . <end> <start> 긴장이 풀리는데요 . <end>
# <start> this site is useful . <end> <start> 이 사이트는 유용합니다 . <end>
# <start> tom looks very sick . <end> <start> 톰은 많이 아파보여 . <end>
# <start> tom must be winning . <end> <start> 톰이 이기고 있나봐 . <end>
# <start> was the bank closed ? <end> <start> 은행 문 닫혀 있었어 ? <end>
# <start> was the bank closed ? <end> <start> 은행 문은 닫혀 있었어요 ? <end>
# <start> watch your language . <end> <start> 입을 조심해라 . <end>
# <start> watch your language . <end> <start> 입조심해라 . <end>
# <start> we had fun with tom . <end> <start> 우리는 톰과 즐거운 시간을 가졌다 . <end>
# <start> what does this mean ? <end> <start> 이게 무슨 뜻이에요 ? <end>
# <start> who taught you that ? <end> <start> 그걸 누가 가르쳐 줬어요 ? <end>
# <start> are these yours , tom ? <end> <start> 탐 , 이것들이 너의 것이야 ? <end>
# <start> blood was everywhere . <end> <start> 피가 여기저기 있었다 . <end>
# <start> can i take a message ? <end> <start> 메세지를 전해 드릴까요 ? <end>
# <start> did you buy cat food ? <end> <start> 고양이 사료 샀어 ? <end>
# <start> dont lie . be honest . <end> <start> 거짓말 하지 마세요 . 솔직해지세요 . <end>
# <start> dont lie . be honest . <end> <start> 거짓말 하지 말고 , 솔직해져 봐 . <end>
# <start> he attempted suicide . <end> <start> 그는 자살을 시도했다 . <end>
# <start> he committed suicide . <end> <start> 그는 자살했다 . <end>
# <start> he is in his library . <end> <start> 그는 그의 서재에 있다 . <end>
# <start> i dont want to live . <end> <start> 살고 싶지 않아 . <end>
# <start> i have money for you . <end> <start> 너에게 줄 돈이 있다 . <end>
# <start> i met tom after work . <end> <start> 난 퇴근 후 톰을 만났다 . <end>
# <start> i now agree with tom . <end> <start> 나는 이제 톰의 의견에 동의한다 . <end>
# <start> i was late to school . <end> <start> 학교에 지각했다 . <end>
# <start> im in the same boat . <end> <start> 나도 같은 처지다 . <end>
# <start> it rarely snows here . <end> <start> 여긴 거의 눈이 안 와 . <end>
# <start> it rarely snows here . <end> <start> 이곳은 눈이 거의 내리지 않습니다 . <end>
# <start> tom is getting coffee . <end> <start> 톰은 커피를 마시고 있어 . <end>
# <start> tom is scared of dogs . <end> <start> 톰은 개를 무서워한다 . <end>
# <start> tom was almost killed . <end> <start> 톰은 죽을 뻔 했어 . <end>
# <start> we ought to leave now . <end> <start> 우리는 지금 떠나야 한다 . <end>
# <start> what do you call this ? <end> <start> 이것을 뭐라고 불러요 ? <end>
# <start> why did you lie to me ? <end> <start> 왜 거짓말했어 ? <end>
# <start> do you come here a lot ? <end> <start> 여기 자주 와 ? <end>
# <start> do you have a nickname ? <end> <start> 별명 있어요 ? <end>
# <start> dont close the window . <end> <start> 창문을 닫지 마 . <end>
# <start> he did nothing but cry . <end> <start> 그는 울기만 했다 . <end>
# <start> he used the dictionary . <end> <start> 그는 사전을 사용했다 . <end>
# <start> i attended his funeral . <end> <start> 나는 장례식에 참석했다 . <end>
# <start> i dont understand you . <end> <start> 선생님의 말씀은 이해가 안 됩니다 . <end>
# <start> i dont understand you . <end> <start> 네가 이해가 안돼 . <end>
# <start> ill meet tom tomorrow . <end> <start> 나 내일 톰 만나려고 . <end>
# <start> im just doing my best . <end> <start> 난 그저 최선을 다하고 있을 뿐이다 . <end>
# <start> no one listens anymore . <end> <start> 더이상 아무도 듣지 않는다 . <end>
# <start> she majors in medicine . <end> <start> 그녀는 의학 전공이다 . <end>
# <start> she majors in medicine . <end> <start> 그녀는 의학을 전공하고 있습니다 . <end>
# <start> thanks for the warning . <end> <start> 경고 고마워 . <end>
# <start> the eggs are still hot . <end> <start> 달걀이 아직 뜨겁다 . <end>
# <start> this clock is accurate . <end> <start> 이 시계는 정확하다 . <end>
# <start> tom doesnt sleep much . <end> <start> 톰은 많이 안 잔다 . <end>
# <start> tom had plenty of help . <end> <start> 톰은 많은 도움을 받았다 . <end>
# <start> tom hasnt decided yet . <end> <start> 톰은 아직 결정하지 못했다 . <end>
# <start> we are on the way home . <end> <start> 우리는 집에 가는 중입니다 . <end>
# <start> were in the same boat . <end> <start> 우리는 같은 배를 탔다 . <end>
# <start> what does it feel like ? <end> <start> 기분이 어때 ? <end>
# <start> what language was that ? <end> <start> 그건 무슨 언어였지 ? <end>
# <start> can i borrow your phone ? <end> <start> 전화기 좀 빌려도 돼 ? <end>
# <start> can you really not swim ? <end> <start> 정말 수영할 줄 몰라 ? <end>
# <start> dont let them hurt tom . <end> <start> 그들이 톰을 다치게 하도록 놔두지 마 . <end>
# <start> he invited me to dinner . <end> <start> 그는 나를 저녁 식사에 초대했다 . <end>
# <start> i also want to be happy . <end> <start> 나도 행복하고 싶다 . <end>
# <start> i always get up at . <end> <start> 나는 항상 아침 시 분에 일어난다 . <end>
# <start> i can hardly believe it . <end> <start> 못 믿겠는데 . <end>
# <start> i dont like this store . <end> <start> 이 가게 마음에 안들어 . <end>
# <start> i hate myself sometimes . <end> <start> 난 가끔 내 자신이 싫어 . <end>
# <start> i hope that i can do it . <end> <start> 내가 할 수 있길 바라 . <end>
# <start> i take back what i said . <end> <start> 아까 한 말 취소야 . <end>
# <start> i want to see you smile . <end> <start> 난 당신이 웃는 걸 보고 싶어요 . <end>
# <start> id like you to go away . <end> <start> 네가 저리 갔으면 좋겠어 . <end>
# <start> im seeing a trend here . <end> <start> 나는 여기서 유행경향을 본다 . <end>
# <start> is this your dictionary ? <end> <start> 이것은 당신의 사전입니까 ? <end>
# <start> kick as hard as you can . <end> <start> 최대한 세게 차 . <end>
# <start> kick as hard as you can . <end> <start> 최대한 세게 차세요 . <end>
# <start> lets get a group photo . <end> <start> 단체 사진을 찍읍시다 . <end>
# <start> lets go somewhere warm . <end> <start> 따뜻한 곳에 가자 . <end>
# <start> our wedding is tomorrow . <end> <start> 우리의 결혼식은 내일이다 . <end>
# <start> sometimes i hate myself . <end> <start> 가끔 내 자신이 싫어 . <end>
# <start> stay a while and listen . <end> <start> 가만히 좀 들어 . <end>
# <start> tell me whats going on . <end> <start> 무슨 일인지 얘기해봐 . <end>
# <start> tell me whats going on . <end> <start> 무슨 일인지 얘기해 주세요 . <end>
# <start> the keys were in my bag . <end> <start> 열쇠는 내 가방에 있었다 . <end>
# <start> this dictionary is mine . <end> <start> 이 사전은 내 것이다 . <end>
# <start> tom certainly thinks so . <end> <start> 톰은 틀림없이 그렇게 생각해 . <end>
# <start> tom is in the same boat . <end> <start> 톰은 같은 처지다 . <end>
# <start> tom looks pretty sleepy . <end> <start> 톰은 상당히 졸려 보인다 . <end>
# <start> tom was totally into it . <end> <start> 탐은 그 것에 푹 빠져 있었다 . <end>
# <start> well take care of that . <end> <start> 우리가 그것을 맡겠다 . 처리하겠다 . <end>
# <start> what do you want to eat ? <end> <start> 뭐 먹고 싶어 ? <end>
# <start> where do you want to go ? <end> <start> 너 어디 가고 싶니 ? <end>
# <start> a square has four angles . <end> <start> 사각형은 각이 개다 . <end>
# <start> can you help me a little ? <end> <start> 조금 도와주실 수 있습니까 ? <end>
# <start> did you make it yourself ? <end> <start> 직접 만드신 거예요 ? <end>
# <start> dont treat me like that . <end> <start> 나를 그렇게 대하지 마 . <end>
# <start> everyone loves a freebie . <end> <start> 모두가 공짜를 좋아한다 . <end>
# <start> greece is an old country . <end> <start> 그리스는 오래된 나라이다 . <end>
# <start> how badly was tom beaten ? <end> <start> 톰이 얼마나 심하게 맞았니 ? <end>
# <start> hows the business going ? <end> <start> 사업 어떻게 되어 가 ? <end>
# <start> i cant live without you . <end> <start> 너 없인 못 살아 . <end>
# <start> i got injured doing that . <end> <start> 제가 그러다가 다쳤었어요 . <end>
# <start> im getting really tired . <end> <start> 나는 정말 피곤해지고 있다 . <end>
# <start> it looks like itll rain . <end> <start> 비가 올 것 같아 . <end>
# <start> please accept my apology . <end> <start> 제 사과를 받아 주세요 . <end>
# <start> samsung is a big company . <end> <start> 삼성은 큰 회사입니다 . <end>
# <start> tell tom that hes wrong . <end> <start> 톰에게 그가 틀렸다고 말해 . <end>
# <start> thats my responsibility . <end> <start> 그것은 나의 책임이다 . <end>
# <start> the boys have gone north . <end> <start> 그 소년들은 북쪽으로 갔다 . <end>
# <start> tom asked for a discount . <end> <start> 톰은 할인을 요청했습니다 . <end>
# <start> tom asked for a discount . <end> <start> 톰은 값을 깎아달라고 했다 . <end>
# <start> were university students . <end> <start> 우리는 대학생입니다 . <end>
# <start> what in the world is this ? <end> <start> 이게 대체 뭐야 ? <end>
# <start> what in the world is this ? <end> <start> 이게 대체 뭐예요 ? <end>
# <start> you will know soon enough . <end> <start> 곧 충분히 알게 될거야 . <end>
# <start> are we going somewhere now ? <end> <start> 지금 어디 가는 길이세요 ? <end>
# <start> do i look desperate to you ? <end> <start> 내가 절박해 보이냐 ? <end>
# <start> do you want some breakfast ? <end> <start> 아침 먹을래 ? <end>
# <start> do you want to take a walk ? <end> <start> 산책하고 싶어 ? <end>
# <start> he made his will last year . <end> <start> 그는 작년에 유언장을 썼습니다 . <end>
# <start> i didnt ask for your help . <end> <start> 너한테 도와달라고 안했거든 . <end>
# <start> i do that almost every day . <end> <start> 나는 그것을 거의 매일 한다 . <end>
# <start> i dont understand english . <end> <start> 나는 영어를 못합니다 . <end>
# <start> i used to be poor like you . <end> <start> 나는 너처럼 가난했었다 . <end>
# <start> i wonder if she is married . <end> <start> 그여자 결혼햿는지 궁금한데 . <end>
# <start> im sorry for interrupting . <end> <start> 끼어 들어서 죄송합니다 . <end>
# <start> im sorry for interrupting . <end> <start> 방해해서 죄송합니다 . <end>
# <start> is there a pharmacy nearby ? <end> <start> 이 근처에 약국 있어요 ? <end>
# <start> it is already nine oclock . <end> <start> 벌써 아홉시다 . <end>
# <start> leave the book where it is . <end> <start> 책을 제자리에 놔 두세요 . <end>
# <start> lets stay friends forever . <end> <start> 언제까지나 친구로 지내자 . <end>
# <start> men like to look masculine . <end> <start> 남자들은 남성적으로 보이고 싶어한다 . <end>
# <start> she says she likes flowers . <end> <start> 그녀는 꽃을 좋아한다고 말했다 . <end>
# <start> tell me where youre going . <end> <start> 어디가는지 말해줘 . <end>
# <start> the medicine tastes bitter . <end> <start> 그 약은 쓰다 . <end>
# <start> the medicine tastes bitter . <end> <start> 그 약은 써요 . <end>
# <start> there are no stars tonight . <end> <start> 오늘 밤엔 별이 안보이네 . <end>
# <start> this house is not for sale . <end> <start> 이 집은 팔려고 내놓은 집 아니에요 . <end>
# <start> tom grew up in the suburbs . <end> <start> tom은 교외에서 자랐다 . <end>
# <start> tom has low blood pressure . <end> <start> 톰은 저혈압이다 . <end>
# <start> tom initialed the document . <end> <start> 탐은 그 문서에 서명했다 . <end>
# <start> tom nodded understandingly . <end> <start> 톰은 이해하고 있다는 듯이 고개를 끄덕였다 . <end>
# <start> tom slammed down the phone . <end> <start> 톰은 전화기를 쾅 놓았다 . <end>
# <start> tom was very disrespectful . <end> <start> 톰은 매우 무례했다 . <end>
# <start> we need to review the case . <end> <start> 우리는 그 사건을 검토할 필요가 있다 . <end>
# <start> we want complete sentences . <end> <start> 우리는 완전한 문장을 원합니다 . <end>
# <start> were all in the same boat . <end> <start> 우리는 모두 같은 배를 탔다 . <end>
# <start> what color is your new car ? <end> <start> 너 새차 색깔이 뭐야 ? <end>
# <start> whos your favorite singer ? <end> <start> 좋아하는 가수가 누구야 ? <end>
# <start> whos your favorite singer ? <end> <start> 좋아하는 가수는 누구예요 ? <end>
# <start> tom kicked the ball really hard . <end> <start> 톰은 정말 세게 공을 찼습니다 . <end>
# <start> tom left us some food and water . <end> <start> 톰은 우리에게 약간의 음식과 물을 남겨주었다 . <end>
# <start> tom put his shirt on inside out . <end> <start> 톰이 셔츠를 뒤집어 입었어 . <end>
# <start> tom wasnt in when i dropped by . <end> <start> 톰은 내가 들렸을 때 없었다 . <end>
# <start> tom wore jeans and a cowboy hat . <end> <start> 톰은 청바지를 입고 카우보이 모자를 썼어 . <end>
# <start> what in the world happened here ? <end> <start> 세상에 여기서 무슨 일이 일어난 거지 ? <end>
# <start> what time are you going to work ? <end> <start> 몇시에 일하러 가 ? <end>
# <start> where did you spend your summer ? <end> <start> 여름방학을 어디서 보내셨어요 ? <end>
# <start> breakfast is served at seven a . m . <end> <start> 아침식사는 오전 시에 제공됩니다 . <end>
# <start> doing that doesnt look too hard . <end> <start> 별로 어려워 보이지 않는 일입니다 . <end>
# <start> dont you feel the house shaking ? <end> <start> 집이 흔들리는거 같지 않아 ? <end>
# <start> he went on walking for two hours . <end> <start> 그는 두 시간 동안 더 걸었다 . <end>
# <start> i guess im just a little sleepy . <end> <start> 그냥 조금 졸린 것 같아 . <end>
# <start> i hadnt seen tom in three years . <end> <start> 지난 년동안 톰을 보지 못했었어요 . <end>
# <start> i know i can count on all of you . <end> <start> 나는 내가 너희 모두를 믿을 수 있다는 것을 안다 . <end>
# <start> i really dont want to miss that . <end> <start> 나는 정말로 그것을 놓치고 싶지 않다 . <end>
# <start> ill stay here till you get back . <end> <start> 나는 네가 돌아올 때까지 여기에 있을 것이다 . <end>
# <start> im going to australia next year . <end> <start> 나는 내년에 호주에 간다 . <end>
# <start> it looks like its going to rain . <end> <start> 비가 올 것 같네요 . <end>
# <start> lets hear the rest of the story . <end> <start> 이야기를 마저 들어보자 . <end>
# <start> lets hear the rest of the story . <end> <start> 이야기를 마저 들어 봅시다 . <end>
# <start> my friend works at a supermarket . <end> <start> 내 친구는 슈퍼마켓에서 일해 . <end>
# <start> some animals are active at night . <end> <start> 어떤 동물들은 야행성이야 . <end>
# <start> to tell the truth , i felt lonely . <end> <start> 실은 나 외로웠어 . <end>
# <start> tom couldnt hold back his anger . <end> <start> 톰은 화를 참을 수 없었다 . <end>
# <start> tom seems like a really nice guy . <end> <start> 톰은 정말 좋은 남자처럼 보인다 . <end>
# <start> we have many varieties of coffee . <end> <start> 우리는 다양한 종류의 커피를 구비하고 있어 . <end>
# <start> where in the world have you been ? <end> <start> 세상에 너 어디에 있었니 ? <end>
# <start> can you help me for just a minute ? <end> <start> 분만 도와주시겠어요 ? <end>
# <start> every country has its own history . <end> <start> 어떤 나라든 역사가 있다 . <end>
# <start> he was at the bottom of the class . <end> <start> 그는 반에서 꼴찌였습니다 . <end>
# <start> he was at the bottom of the class . <end> <start> 걔는 반에서 꼴찌였어 . <end>
# ...
# <start> tom works in research and development . <end> <start> 톰은 연구 개발을 하고 있어요 . <end>
# <start> what do you think this sentence means ? <end> <start> 이 문장이 무슨 뜻인 것 같아 ? <end>
# <start> remember that were all in the same boat . <end> <start> 우리 모두가 같은 한 배를 탔다는 걸 기억해라 . <end>
# <start> she is always at the bottom of the class . <end> <start> 그녀는 항상 반에서 꼴찌입니다 . <end>
# <start> she is always at the bottom of the class . <end> <start> 걔는 항상 반에서 꼴찌야 . <end>
# <start> the price of gold varies from day to day . <end> <start> 금값은 매일 변한다 . <end>
# <start> we graduate from high school at eighteen . <end> <start> 우리는 살에 고등학교를 졸업합니다 . <end>
# <start> we graduate from high school at eighteen . <end> <start> 우리는 살에 고등학교를 졸업해 . <end>
# <start> where did you spend your summer vacation ? <end> <start> 여름방학을 어디서 보냈어 ? <end>
# <start> where did you spend your summer vacation ? <end> <start> 여름방학을 어디서 보내셨어요 ? <end>
# <start> have you met any canadians here in boston ? <end> <start> 여기 보스턴에서 캐나다 사람을 만난 적이 있나요 ? <end>
# <start> how do you calculate the volume of a cube ? <end> <start> 정육면체의 부피를 어떻게 계산합니까 ? <end>
# <start> i should have told you everything earlier . <end> <start> 너한테 모든 걸 좀 더 빨리 얘기했어야 했는데 . <end>
# <start> now we have one less thing to worry about . <end> <start> 이제 우리는 걱정 거리가 하나 줄었다 . <end>
# <start> she is more beautiful than any other girl . <end> <start> 그녀는 누구보다도 아름다워요 . <end>
# <start> there is no bus service after ninethirty . <end> <start> 시 반 이후엔 버스가 다니지 않아요 . <end>
# <start> tom isnt likely to pass the driving test . <end> <start> 톰은 운전면허 시험에 떨어질 듯 하다 . <end>
# <start> tom should be here within fifteen minutes . <end> <start> 톰은 십오분 안에 여기에 있어야 해 . <end>
# <start> we dont know whether tom can come or not . <end> <start> 우리는 톰이 올수 있을지 없을지 모릅니다 . <end>
# <start> have you ever seen tom not wearing glasses ? <end> <start> 톰이 안경 벗은 거 본 적 있어 ? <end>
# <start> i have some strawberries . do you want some ? <end> <start> 딸기가 있는데 너 먹고 싶니 ? <end>
# <start> there is nothing you have to be ashamed of . <end> <start> 부끄러워 할 거 없어요 . <end>
# <start> tom liked to listen to mary play the piano . <end> <start> 톰은 메리가 피아노 치는 것을 듣는 것을 좋아했다 . <end>
# <start> tom told me where i could buy pomegranates . <end> <start> 톰이 어디서 석류를 살 수 있는지 말해 주었다 . <end>
# <start> he often attributes his success to his wife . <end> <start> 그는 종종 그의 성공을 그의 아내의 공으로 돌리곤 한다 <end>
# <start> i didnt know that you used to teach french . <end> <start> 나는 네가 프랑스어를 가르쳤는지 몰랐어 <end>
# <start> i have to take the entrance exams next year . <end> <start> 나 내년에 입학시험을 봐야 돼 . <end>
# <start> its not as easy to do that as people think . <end> <start> 사람들이 생각하는 것 만큼 쉽지는 않아요 . <end>
# <start> people who ignore history tend to repeat it . <end> <start> 역사를 무시하는 사람들은 역사를 되풀이하게 된다 . <end>
# <start> shut up . if you dont , youll be thrown out . <end> <start> 닥쳐 . 안그러면 쫓아낼거야 . <end>
# <start> tom and mary live in a very small apartment . <end> <start> 톰과 메리는 매우 작은 아파트에 살고 있어요 . <end>
# <start> tom told his friends that he never ate meat . <end> <start> 톰은 친구들에게 고기를 먹은 적이 한 번도 없다고 했다 . <end>
# <start> tom went to korea as a christian missionary . <end> <start> 톰은 선교사로서 한국에 갔다 . <end>
# <start> toms birthday was the day before yesterday . <end> <start> 톰의 생일은 그저께였다 . <end>
# <start> what in the world do you think youre doing ? <end> <start> 세상에 네가 뭘 하고 있다고 생각하는 거니 ? <end>
# <start> certain religions are against organ donation . <end> <start> 어떤 종교는 장기 기증을 금지하기도 해 . <end>
# <start> dont add sentences from copyrighted sources . <end> <start> 저작권이 있는 출처의 문장을 추가하지 마십시오 . <end>
# <start> dont sign the document until youve read it . <end> <start> 서류를 읽기 전에는 사인하지 마세요 <end>
# <start> i havent been getting a lot of sleep lately . <end> <start> 나는 요즘 잠을 많이 못잤어요 . <end>
# <start> im looking for a hat to match a brown dress . <end> <start> 갈색 드레스와 어울리는 모자를 찾고 있어요 . <end>
# <start> ive read your book . it was very interesting . <end> <start> 당신 책을 읽어봤었어요 . 꽤 흥미롭더라구요 . <end>
# <start> this year , valentines day falls on a sunday . <end> <start> 올해는 발렌타인 데이가 일요일이다 . <end>
# <start> upon hearing the news , she broke down crying . <end> <start> 그녀는 그 소식을 듣자마자 울음을 터뜨렸다 . <end>
# <start> upon hearing the news , she broke down crying . <end> <start> 그녀는 그 소식을 듣자마자 , 울음을 터뜨렸습니다 . <end>
# <start> tom lives in a small apartment on park street . <end> <start> 톰은 파크 스트리트의 작은 아파트에서 살고 있다 . <end>
# <start> you havent told tom youre married , have you ? <end> <start> 너 결혼한거 톰한테 말 안했구나 , 그치 ? <end>
# <start> you look tired , so you should go to bed early . <end> <start> 피곤해 보이니까 일찍 자는 것이 좋겠다 . <end>
# <start> how many boys do you have ? i only have one . <end> <start> 형제가 몇 명이나 있어 ? 한 명 있어 . <end>
# <start> it requires more courage to suffer than to die . <end> <start> 죽는 일보다 고통 받는 일이 더 많은 용기를 필요로 한다 . <end>
# <start> the mona lisa was painted by leonardo da vinci . <end> <start> 모나리자는 레오나르도 다빈치가 그렸어 . <end>
# <start> tom currently lives alone in a small apartment . <end> <start> 탐은 현재 작은 아파트에서 혼자 살고 있다 . <end>
# <start> you need good equipment to climb that mountain . <end> <start> 저 산에 오르려면 좋은 장비가 있어야 돼 . <end>
# <start> are there any students from korea in your class ? <end> <start> 너의 반에 한국에서 온 학생이 있니 ? <end>
# <start> tom says he doesnt think mary ought to do that . <end> <start> 톰은 마리가 그것을 해야만 한다고 생각하지 않는다고 말했다 . <end>
# <start> tom told mary he wouldnt let her go by herself . <end> <start> 톰은 메리에게 그는 그녀를 혼자 가게 하지는 않겠다고 말했다 . <end>
# <start> were moving to boston at the end of this month . <end> <start> 우리는 이달 말에 보스턴으로 이사를 합니다 . <end>
# <start> you had bacon and eggs for breakfast , didnt you ? <end> <start> 아침에 베이건이랑 달걀 먹었잖아 , 그치 ? <end>
# <start> its difficult for me to express myself in french . <end> <start> 프랑스어로 자기소개를 하는 것은 내게 어려운 일이다 . <end>
# <start> this english book is too difficult for me to read . <end> <start> 이 영어 책은 내가 읽기엔 너무 어렵다 . <end>
# <start> tom said he didnt want to go to the park with us . <end> <start> 톰은 우리랑 같이 공원에 가고 싶지 않대 . <end>
# <start> he left the office without saying a word to anyone . <end> <start> 그는 사람들에게 말 한 마디 없이 사무실을 떠났다 . <end>
# <start> i used to go swimming in the sea when i was a child . <end> <start> 내가 어릴 때는 바다에 수영하러 가곤 했었지 . <end>
# <start> if it is worth doing at all , it is worth doing well . <end> <start> 할 가치가 있는 일이면 , 제대로 하십시오 . <end>
# <start> is there anything you want us to send you from home ? <end> <start> 우리가 집에서 너에게 보내줬으면 하는 거 없니 ? <end>
# <start> there are more than six billion people in the world . <end> <start> 지구상의 인구는 억 이상이야 . <end>
# <start> could you please tell me again where you put the key ? <end> <start> 키를 어디다 뒀는지 다시 얘기해 주시겠어요 ? <end>
# <start> he breathed deeply before entering his bosss office . <end> <start> 그는 상사의 사무실로 들어가기 전에 심호흡을 했다 . <end>
# <start> i am not quite sure if we can meet your requirements . <end> <start> 우리가 당신의 요구를 충족시켜 드릴 수 있을지 모르겠네요 . <end>
# <start> i dont have much money , but i can get along somehow . <end> <start> 나는 돈이 별로 없지만 , 그럭저럭 지낼 수 있다 <end>
# <start> weather permitting , well start on our trip tomorrow . <end> <start> 날씨가 허락한다면 , 우리는 내일 여행을 시작할 것이다 . <end>
# <start> her dress attracted everyones attention at the party . <end> <start> 그 여자가 파티에 입고 온 드레스가 사람들의 눈길을 끌었지 . <end>
# <start> please come here between two and three this afternoon . <end> <start> 오늘 오후 두시에서 세시 사이에 여기로 와 주세요 . <end>
# <start> whats the difference between religion and philosophy ? <end> <start> 종교와 철학의 차이점은 무엇입니까 ? <end>
# <start> everyone wants to go to heaven , but nobody wants to die . <end> <start> 모두 천국에 가고 싶어 하나 , 누구도 죽고 싶어 하지 않는다 . <end>
# <start> its not fair to attribute your failure to your parents . <end> <start> 당신의 실패를 당신의 부모님 탓으로 돌리는것은 옳지 않습니다 <end>
# <start> the company president was indicted for paying kickbacks . <end> <start> 그 회사 회장은 리베이트를 지불한 혐의로 기소되었다 . <end>
# <start> if it were not for water , human life would be impossible . <end> <start> 물이 없었다면 인류의 생존은 가능하지 않았을 겁니다 . <end>
# <start> this bike isnt safe to ride the wheel wobbles too much . <end> <start> 이 바이크는 별로 안전하지 않아 . 바퀴가 너무 흔들려 . <end>
# <start> tom doesnt want to spend the rest of his life in prison . <end> <start> 톰은 남은 인생을 감옥에서 보내고 싶어하지 않아 . <end>
# <start> if god did not exist , it would be necessary to invent him . <end> <start> 만약 신이 존재하지 않았다면 , 만들어 낼 필요가 있겠지 . <end>
# <start> tom says he needs to talk to us about something important . <end> <start> 톰이 우리한테 뭔가 중요한걸 얘기하고 싶다는데 . <end>
# <start> i can smell marys perfume . she must have been here earlier . <end> <start> 나는 메리의 향수 냄새를 맡을 수 있다 . 그녀는 좀 전에 여기에 있었음에 틀림없다 . <end>
# <start> is there a place where i can charge my cellphone around here ? <end> <start> 이 근처에 휴대폰 충전할 수 있는 곳이 있나요 ? <end>
# <start> im going through my closet to find clothes to give to charity . <end> <start> 옷장을 뒤져서 기부할 옷들을 찾아봐야겠어 . <end>
# <start> tom gave mary some advice on how to pass multiplechoice tests . <end> <start> 탐은 메리에게 선다형 시험에 통과하는 방법에 대해 조언했다 . <end>
# <start> how can anyone trust anything tom says ? hes a pathological liar . <end> <start> 어떻게 누군가가 톰이 말하는 것을 믿을 수 있지 ? 그는 병적인 거짓말쟁이야 . <end>
# <start> after driving for eight hours , tom just couldnt drive any longer . <end> <start> 시간 동안 운전을 한 후에 톰은 더이상 운전을 할 수 없었다 . <end>
# <start> i thought you might be lonely , so i came over with a bottle of wine . <end> <start> 니가 좀 외로울 것 같아서 내가 와인 한 병을 들고 왔지 . <end>
# <start> i looked for the key under the welcome mat and in the nearby flower pot . <end> <start> 나는 열쇠를 찾기 위해 현관 매트 아래와 근처 화분 안을 뒤졌다 . <end>
# <start> tom occasionally prods me to work out with him , but im really not interested . <end> <start> 톰은 때때로 같이 운동하자고 졸라댔지만 나는 정말 운동에 관심이 없다 . <end>
# <start> i think i can speak french well enough to say pretty much anything i want to say . <end> <start> 나는 내가 말하고 싶은 것은 거의 다 말할 수 있을 정도로 불어를 잘 한다고 생각한다 . <end>
# <start> its not always possible to eat well when youre traveling in this part of the world . <end> <start> 당신이 세계를 여행하는 동안 , 항상 잘먹는 것이 가능하지는 않습니다 . <end>
# <start> make a good translation of the sentence that you are translating . dont let translations into other languages influence you . <end> <start> 당신이 번역할 문장에 충실하게 번역하십시오 . 다른 언어로 번역된 문장의 영향을 받지 마십시오 . <end>

# %%
def max_length(tensor):
    return max(len(t) for t in tensor)

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
    # creating cleaned input, output pairs
    targ_lang, inp_lang = create_dataset(path, num_examples)

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)
#
# Training on the complete dataset of >100,000 sentences will take a long time. To train faster, we can limit the size of the dataset to 5,000 sentences (of course, translation quality degrades with less data):

# %%
# Try experimenting with the size of that dataset
num_examples = 5000
# input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file_ko, num_examples)
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = max_length(target_tensor), max_length(input_tensor)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val)
# Out:
# (639, 639, 160, 160)

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 526 ----> 저희에게
# 17 ----> 거짓말
# 19 ----> 하지
# 44 ----> 마세요
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 14 ----> dont
# 41 ----> lie
# 7 ----> to
# 71 ----> us
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# WARNING:tensorflow:From /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages/tensorflow/python/data/ops/iterator_ops.py:532: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# (TensorShape([Dimension(64), Dimension(18)]),
#  TensorShape([Dimension(64), Dimension(23)]))

# %% [markdown]
# ## Write the encoder and decoder model
#
# Here, we'll implement an encoder-decoder model with attention which you can read about in the TensorFlow [Neural Machine Translation (seq2seq) tutorial](https://www.tensorflow.org/tutorials/seq2seq). This example uses a more recent set of APIs. This notebook implements the [attention equations](https://www.tensorflow.org/tutorials/seq2seq#background_on_the_attention_mechanism) from the seq2seq tutorial. The following diagram shows that each input words is assigned a weight by the attention mechanism which is then used by the decoder to predict the next word in the sentence.
#
# <img src="https://www.tensorflow.org/images/seq2seq/attention_mechanism.jpg" width="500" alt="attention mechanism">
#
# The input is put through an encoder model which gives us the encoder output of shape *(batch_size, max_length, hidden_size)* and the encoder hidden state of shape *(batch_size, hidden_size)*.
#
# Here are the equations that are implemented:
#
# <img src="https://www.tensorflow.org/images/seq2seq/attention_equation_0.jpg" alt="attention equation 0" width="800">
# <img src="https://www.tensorflow.org/images/seq2seq/attention_equation_1.jpg" alt="attention equation 1" width="800">
#
# We're using *Bahdanau attention*. Lets decide on notation before writing the simplified form:
#
# * FC = Fully connected (dense) layer
# * EO = Encoder output
# * H = hidden state
# * X = input to the decoder
#
# And the pseudo-code:
#
# * `score = FC(tanh(FC(EO) + FC(H)))`
# * `attention weights = softmax(score, axis = 1)`. Softmax by default is applied on the last axis but here we want to apply it on the *1st axis*, since the shape of score is *(batch_size, max_length, hidden_size)*. `Max_length` is the length of our input. Since we are trying to assign a weight to each input, softmax should be applied on that axis.
# * `context vector = sum(attention weights * EO, axis = 1)`. Same reason as above for choosing axis as 1.
# * `embedding output` = The input to the decoder X is passed through an embedding layer.
# * `merged vector = concat(embedding output, context vector)`
# * This merged vector is then given to the GRU
#
# The shapes of all the vectors at each step have been specified in the comments in the code:

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 18, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # hidden shape == (batch_size, hidden size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden size)
    # we are doing this to perform addition to calculate the score
    hidden_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, hidden_size)
    score = self.V(tf.nn.tanh(
        self.W1(values) + self.W2(hidden_with_time_axis)))

    # attention_weights shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 18, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((64, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 1056)

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.train.AdamOptimizer()
loss_object = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# ## Training
#
# 1. Pass the *input* through the *encoder* which return *encoder output* and the *encoder hidden state*.
# 2. The encoder output, encoder hidden state and the decoder input (which is the *start token*) is passed to the decoder.
# 3. The decoder returns the *predictions* and the *decoder hidden state*.
# 4. The decoder hidden state is then passed back into the model and the predictions are used to calculate the loss.
# 5. Use *teacher forcing* to decide the next input to the decoder.
# 6. *Teacher forcing* is the technique where the *target word* is passed as the *next input* to the decoder.
# 7. The final step is to calculate the gradients and apply it to the optimizer and backpropagate.

# %%
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 10

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
        print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                     batch,
                                                     batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# WARNING:tensorflow:From /home/jsyoon/anaconda3/envs/tf1/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1 Batch 0 Loss 2.6064
# Epoch 1 Loss 2.1053
# Time taken for 1 epoch 6.291437864303589 sec
#
# Epoch 2 Batch 0 Loss 1.9134
# Epoch 2 Loss 1.7374
# Time taken for 1 epoch 6.872637987136841 sec
#
# Epoch 3 Batch 0 Loss 1.6448
# Epoch 3 Loss 1.6038
# Time taken for 1 epoch 6.339382171630859 sec
#
# Epoch 4 Batch 0 Loss 1.6269
# Epoch 4 Loss 1.5521
# Time taken for 1 epoch 7.060424089431763 sec
#
# Epoch 5 Batch 0 Loss 1.4979
# Epoch 5 Loss 1.4843
# Time taken for 1 epoch 6.285207748413086 sec
#
# Epoch 6 Batch 0 Loss 1.5366
# Epoch 6 Loss 1.4439
# Time taken for 1 epoch 6.5822060108184814 sec
#
# Epoch 7 Batch 0 Loss 1.3533
# Epoch 7 Loss 1.3819
# Time taken for 1 epoch 6.252370834350586 sec
#
# Epoch 8 Batch 0 Loss 1.3275
# Epoch 8 Loss 1.3422
# Time taken for 1 epoch 6.861409664154053 sec
#
# Epoch 9 Batch 0 Loss 1.3992
# Epoch 9 Loss 1.3004
# Time taken for 1 epoch 6.576773643493652 sec
#
# Epoch 10 Batch 0 Loss 1.2565
# Epoch 10 Loss 1.2735
# Time taken for 1 epoch 7.189443588256836 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess_sentence(sentence)

    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                           maxlen=max_length_inp,
                                                           padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                             dec_hidden,
                                                             enc_out)

        # storing the attention weights to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += targ_lang.index_word[predicted_id] + ' '

        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence, attention_plot

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')

    fontdict = {'fontsize': 14}

    ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
    ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

    plt.show()

# %%
def translate(sentence):
    result, sentence, attention_plot = evaluate(sentence)

    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

    attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
    plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate(u'hace mucho frio aqui.') #It's really cold here
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-ffc09aa820b4> in <module>
# ----> 1 translate(u'hace mucho frio aqui.') #It's really cold here
#
# <ipython-input-28-c5a87b4b04cb> in translate(sentence)
#       1 def translate(sentence):
# ----> 2     result, sentence, attention_plot = evaluate(sentence)
#       3
#       4     print('Input: %s' % (sentence))
#       5     print('Predicted translation: {}'.format(result))
#
# <ipython-input-26-c0c36431ad2f> in evaluate(sentence)
#       4     sentence = preprocess_sentence(sentence)
#       5
# ----> 6     inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7     inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                            maxlen=max_length_inp,
#
# <ipython-input-26-c0c36431ad2f> in <listcomp>(.0)
#       4     sentence = preprocess_sentence(sentence)
#       5
# ----> 6     inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7     inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                            maxlen=max_length_inp,
#
# KeyError: 'hace'

# %%
translate(u'esta es mi vida.') #this is my life

# %%
translate(u'¿todavia estan en casa?') #Are you still at home?

# %%
# wrong translation
translate(u'trata de averiguarlo.') #try to find out.
# translate(u'김치')
