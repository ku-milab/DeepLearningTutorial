# %% [markdown]
# # Word2Vec
# Revised for SKT Deep Learning Lecture
# Originally from tensorflow.org

# %%
# !pip install tensorflow-gpu==1.13.1

import argparse
import collections
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector
# Out:
# Requirement already satisfied: tensorflow-gpu==1.13.1 in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.16.4)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.13.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.0.7)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.15.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.33.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.8.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (3.7.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.13.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.0.9)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (0.15.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.13.1) (41.0.1)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (3.0.5)

# %%
data_index = 0

current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

log_dir = os.path.join(current_path, 'log')

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

# %%
# Step 1: Download the data.
def maybe_download(url, filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename, local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename

filename = maybe_download('http://mattmahoney.net/dc/', 'text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = {}
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = []
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, unused_dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit
# the validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/gpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal([vocabulary_size, embedding_size],
                              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all
  # embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned
    # "summary" variable. Feed metadata variable to session for visualizing
    # the graph in TensorBoard.
    _, summary, loss_val = session.run([optimizer, merged, loss],
                                       feed_dict=feed_dict,
                                       run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000
      # batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in
  # TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  286.22344970703125
# Nearest to would: carefully, ski, contracting, exert, filmfour, yearning, republican, montrealers,
# Nearest to zero: actuality, redstone, birth, obstructing, emigrant, nugget, gardens, influenza,
# Nearest to a: niz, archer, referred, renamed, teletext, clitoral, balti, across,
# Nearest to first: bankruptcy, microfluidics, russians, sidebands, excuse, leaf, gottfried, magick,
# Nearest to had: waterfowl, grunwald, diphthong, outsider, parcham, meets, doc, unfairness,
# Nearest to by: metaxas, lenin, characterizing, dalnet, accompany, nsted, niki, concealed,
# Nearest to between: nils, coatings, deemed, comedies, jeffreys, sell, prehistory, premier,
# Nearest to it: credo, blond, modernist, weil, glycoproteins, assay, clipped, subroutine,
# Nearest to when: palm, frisia, borda, harmonizing, agena, thorne, chaplin, rivalries,
# Nearest to however: unto, electronegative, noted, packet, shakespearean, browning, marathas, macleod,
# Nearest to to: crosses, rape, rejoice, brahms, inflate, marburg, vanuatu, thigh,
# Nearest to be: plurals, lawful, outspoken, daemen, mitchell, versions, zygote, national,
# Nearest to he: besieged, wavetable, monolingual, larp, florin, brodsky, dhabi, replace,
# Nearest to there: merges, supercharger, captained, paleontologists, gesserit, niccol, sponsorship, dhimmis,
# Nearest to most: pools, corsican, joplin, plasmas, makran, kitts, apprentice, magog,
# Nearest to if: gigabytes, leans, dms, costumes, descendants, pickens, completes, dogs,
# Average loss at step  2000 :  113.49106315803527
# Average loss at step  4000 :  52.69882666134834
# Average loss at step  6000 :  33.48023687720299
# Average loss at step  8000 :  23.956031764149667
# Average loss at step  10000 :  18.184196661114694
# Nearest to would: republican, exert, a, ski, leo, nine, boeing, false,
# Nearest to zero: nine, one, eight, six, altenberg, phi, gland, agave,
# Nearest to a: the, UNK, and, one, bckgr, touchdown, an, austin,
# Nearest to first: hypotheses, cast, bankruptcy, mountainous, stg, sidebands, of, retroviral,
# Nearest to had: has, european, were, became, meets, credited, darius, arena,
# Nearest to by: in, and, with, of, is, UNK, were, accompany,
# Nearest to between: coatings, sell, nine, annexation, comedies, fao, cliff, deemed,
# Nearest to it: he, tora, nights, fao, weight, afghan, this, contribution,
# Nearest to when: eight, gland, correction, gerald, bckgr, fawcett, eurasia, palm,
# Nearest to however: noted, barbuda, macleod, wants, shorthand, structures, archie, unto,
# Nearest to to: in, and, strictly, bckgr, yeast, stereotypical, storm, notorious,
# Nearest to be: as, versions, austin, hubbard, notorious, offered, gb, instant,
# Nearest to he: it, and, also, benefits, criminal, gb, solf, platforms,
# Nearest to there: coke, defeats, nitride, fao, ampere, afghanistan, allies, strongly,
# Nearest to most: pools, solf, gathered, damascus, appendix, quarters, archie, nomenclature,
# Nearest to if: eight, gang, fao, costumes, nine, completes, towns, will,
# Average loss at step  12000 :  13.776709837317467
# Average loss at step  14000 :  11.652263345956802
# Average loss at step  16000 :  9.771530268430709
# Average loss at step  18000 :  8.498993307948112
# Average loss at step  20000 :  8.06140232682228
# Nearest to would: may, gum, can, exert, republican, has, leo, ski,
# Nearest to zero: nine, six, five, eight, dasyprocta, four, seven, three,
# Nearest to a: the, dasyprocta, agouti, circ, this, UNK, bckgr, three,
# Nearest to first: operatorname, cast, mountainous, hypotheses, bankruptcy, stg, martha, use,
# Nearest to had: has, was, were, european, is, became, agouti, have,
# Nearest to by: in, and, with, is, was, as, gollancz, for,
# Nearest to between: with, coatings, cliff, in, sell, nebulae, of, annexation,
# Nearest to it: he, this, tora, which, the, weil, agouti, nights,
# Nearest to when: chaplin, and, eurasia, gerald, eight, dasyprocta, gland, though,
# Nearest to however: that, and, noted, amazonas, wants, shorthand, barbuda, unto,
# Nearest to to: in, and, for, agouti, nine, bckgr, yeast, may,
# Nearest to be: have, as, is, mitchell, by, are, austin, was,
# Nearest to he: it, and, they, there, also, who, eight, benefits,
# Nearest to there: he, defeats, nitride, coke, and, ampere, agouti, UNK,
# Nearest to most: pools, gathered, aisha, solf, damascus, triumphant, resonant, nomenclature,
# Nearest to if: will, venomous, gang, aoc, costumes, eight, fao, gum,
# Average loss at step  22000 :  7.0382889548540115
# Average loss at step  24000 :  6.917678050637245
# Average loss at step  26000 :  6.747115566730499
# Average loss at step  28000 :  6.343349883675575
# Average loss at step  30000 :  5.927044131994247
# Nearest to would: can, may, almighty, could, gum, to, has, exert,
# Nearest to zero: five, six, eight, seven, four, nine, dasyprocta, three,
# Nearest to a: the, dasyprocta, this, agouti, tonnage, bckgr, some, operatorname,
# Nearest to first: operatorname, cast, bankruptcy, chalukyas, mountainous, hypotheses, stg, martha,
# Nearest to had: has, was, were, have, is, european, agouti, became,
# Nearest to by: in, with, was, and, were, as, gollancz, agouti,
# Nearest to between: with, of, in, coatings, cliff, from, annexation, amaranthus,
# Nearest to it: he, this, which, tora, agouti, there, fao, reasonably,
# Nearest to when: chaplin, and, though, but, eurasia, six, adventist, where,
# Nearest to however: that, and, noted, wants, amazonas, shorthand, structures, although,
# Nearest to to: for, bckgr, agouti, nine, in, may, and, yeast,
# Nearest to be: have, is, are, mitchell, by, as, were, was,
# Nearest to he: it, they, there, who, and, eight, benefits, also,
# Nearest to there: he, it, they, defeats, nitride, abet, which, and,
# Nearest to most: pools, gathered, birkenau, damascus, aisha, triumphant, many, solf,
# Nearest to if: will, venomous, cordoba, aoc, costumes, gum, gang, fao,
# Average loss at step  32000 :  5.929954000949859
# Average loss at step  34000 :  5.747913481712342
# Average loss at step  36000 :  5.7965916814804075
# Average loss at step  38000 :  5.490070511341095
# Average loss at step  40000 :  5.252834008693695
# Nearest to would: can, may, almighty, could, will, gum, has, republican,
# Nearest to zero: eight, five, seven, six, four, nine, dasyprocta, three,
# Nearest to a: the, kifl, dasyprocta, agouti, tonnage, any, operatorname, some,
# Nearest to first: operatorname, bankruptcy, cast, hypotheses, chalukyas, martha, mountainous, restoration,
# Nearest to had: has, was, have, were, became, agouti, is, behaves,
# Nearest to by: was, in, with, gollancz, operatorname, were, be, agouti,
# Nearest to between: with, in, of, from, cliff, coatings, annexation, amaranthus,
# Nearest to it: he, this, which, tora, there, that, agouti, reasonably,
# Nearest to when: chaplin, where, in, though, and, but, if, eurasia,
# Nearest to however: that, and, but, although, wants, noted, when, barbuda,
# Nearest to to: nine, zero, bckgr, agouti, in, narrowest, asic, strictly,
# Nearest to be: have, are, were, by, is, mitchell, been, as,
# Nearest to he: it, they, there, who, she, albury, aam, eight,
# Nearest to there: he, it, they, nitride, which, defeats, abet, but,
# Nearest to most: pools, gathered, birkenau, damascus, many, aisha, teen, triumphant,
# Nearest to if: will, venomous, when, cordoba, aoc, gum, costumes, gang,
# Average loss at step  42000 :  5.35724002301693
# Average loss at step  44000 :  5.2421082582473755
# Average loss at step  46000 :  5.216171346545219
# Average loss at step  48000 :  5.217479574084282
# Average loss at step  50000 :  4.982731312394142
# Nearest to would: can, may, will, could, almighty, must, gum, might,
# Nearest to zero: seven, eight, five, six, nine, four, dasyprocta, three,
# Nearest to a: the, this, tonnage, dasyprocta, agouti, any, amok, operatorname,
# Nearest to first: operatorname, cast, bankruptcy, gundam, lysosomes, restoration, hypotheses, martha,
# Nearest to had: has, was, have, were, is, became, behaves, agouti,
# Nearest to by: was, gollancz, be, as, from, in, with, eight,
# Nearest to between: with, in, from, coatings, kapoor, cliff, annexation, amaranthus,
# Nearest to it: he, this, which, tora, there, kifl, agouti, cowan,
# Nearest to when: if, where, but, for, though, kapoor, four, and,
# Nearest to however: that, but, and, although, kapoor, wants, operatorname, agouti,
# Nearest to to: for, nine, agouti, bckgr, and, abet, can, should,
# Nearest to be: have, is, are, by, was, were, mitchell, been,
# Nearest to he: it, they, who, there, she, albury, aam, eight,
# Nearest to there: it, he, they, nitride, which, but, abet, defeats,
# Nearest to most: pools, gathered, more, many, damascus, teen, aisha, birkenau,
# Nearest to if: when, will, venomous, cordoba, although, gum, but, costumes,
# Average loss at step  52000 :  5.0474144698381425
# Average loss at step  54000 :  5.2108256819248195
# Average loss at step  56000 :  5.045917860627174
# Average loss at step  58000 :  5.067224151968956
# Average loss at step  60000 :  4.969010336995125
# Nearest to would: can, may, will, could, must, almighty, might, should,
# Nearest to zero: eight, seven, six, five, nine, four, three, dasyprocta,
# Nearest to a: the, any, michelob, kifl, amok, agouti, this, dasyprocta,
# Nearest to first: operatorname, cast, thx, bankruptcy, lysosomes, dasyprocta, second, last,
# Nearest to had: has, have, was, were, agouti, behaves, is, became,
# Nearest to by: was, as, be, gollancz, with, eight, from, angolan,
# Nearest to between: with, in, cliff, from, during, amaranthus, annexation, coatings,
# Nearest to it: he, this, which, there, tora, they, she, kifl,
# Nearest to when: if, where, six, kapoor, after, though, but, five,
# Nearest to however: that, but, although, and, kapoor, operatorname, agouti, when,
# Nearest to to: nine, will, for, agouti, bckgr, can, asic, not,
# Nearest to be: have, been, was, mitchell, by, were, are, is,
# Nearest to he: it, they, she, who, there, albury, aam, eight,
# Nearest to there: it, they, he, which, nitride, abet, who, this,
# Nearest to most: pools, many, more, gathered, some, damascus, teen, triumphant,
# Nearest to if: when, will, although, venomous, but, cordoba, gum, costumes,
# Average loss at step  62000 :  5.010541734814644
# Average loss at step  64000 :  4.833386286735535
# Average loss at step  66000 :  4.6017647405862805
# Average loss at step  68000 :  4.979710987329483
# Average loss at step  70000 :  4.897943478465081
# Nearest to would: can, may, will, could, must, might, should, almighty,
# Nearest to zero: eight, five, seven, six, four, nine, three, dasyprocta,
# Nearest to a: the, thaler, any, amok, kifl, tonnage, dasyprocta, michelob,
# Nearest to first: operatorname, second, last, thx, gundam, bankruptcy, hagbard, cast,
# Nearest to had: has, have, was, were, became, behaves, been, agouti,
# Nearest to by: be, was, as, gollancz, with, agouti, been, operatorname,
# Nearest to between: with, cliff, during, from, amaranthus, annexation, in, coatings,
# Nearest to it: he, this, there, which, she, tora, they, agouti,
# Nearest to when: if, where, but, kapoor, after, though, and, six,
# Nearest to however: but, that, although, kapoor, and, when, which, agouti,
# Nearest to to: will, agouti, narrowest, mitral, may, bckgr, not, should,
# Nearest to be: been, have, by, were, are, was, mitchell, is,
# Nearest to he: it, they, she, who, there, aam, exclaimed, albury,
# Nearest to there: they, it, he, nitride, which, often, generally, still,
# Nearest to most: more, pools, gathered, many, teen, some, damascus, corsican,
# Nearest to if: when, although, but, will, venomous, cordoba, costumes, gum,
# Average loss at step  72000 :  4.752149122238159
# Average loss at step  74000 :  4.8081869976520535
# Average loss at step  76000 :  4.732298429250717
# Average loss at step  78000 :  4.80478659081459
# Average loss at step  80000 :  4.7912011427879335
# Nearest to would: can, may, will, could, might, must, should, almighty,
# Nearest to zero: five, four, six, eight, seven, nine, dasyprocta, three,
# Nearest to a: the, thaler, dasyprocta, michelob, agouti, any, amok, tonnage,
# Nearest to first: second, last, operatorname, hagbard, upper, gundam, massacre, thx,
# Nearest to had: has, have, was, were, became, behaves, been, agouti,
# Nearest to by: was, gollancz, as, be, in, agouti, with, been,
# Nearest to between: with, in, from, cliff, annexation, during, amaranthus, coatings,
# Nearest to it: he, this, there, she, which, tora, they, agouti,
# Nearest to when: if, where, but, though, kapoor, after, however, dasyprocta,
# Nearest to however: but, that, although, kapoor, when, during, and, operatorname,
# Nearest to to: agouti, bckgr, mitral, will, nine, can, dasyprocta, abet,
# Nearest to be: been, have, were, was, by, are, is, mitchell,
# Nearest to he: it, they, she, who, there, aam, exclaimed, suspense,
# Nearest to there: they, it, he, often, which, nitride, still, generally,
# Nearest to most: more, many, some, pools, gathered, teen, damascus, rarities,
# Nearest to if: when, although, but, venomous, will, cordoba, costumes, gum,
# Average loss at step  82000 :  4.761652750015259
# Average loss at step  84000 :  4.763458754658699
# Average loss at step  86000 :  4.768380765080452
# Average loss at step  88000 :  4.732830902695656
# Average loss at step  90000 :  4.732378616809845
# Nearest to would: can, may, will, could, might, must, should, cannot,
# Nearest to zero: five, eight, seven, six, four, nine, dasyprocta, three,
# Nearest to a: the, any, thaler, dasyprocta, amok, kifl, michelob, agouti,
# Nearest to first: second, last, operatorname, massacre, next, bankruptcy, hagbard, upper,
# Nearest to had: has, have, was, were, became, behaves, gollancz, been,
# Nearest to by: as, was, with, gollancz, during, agouti, be, dasyprocta,
# Nearest to between: with, in, from, during, annexation, cliff, amaranthus, criticizes,
# Nearest to it: he, this, there, she, which, they, tora, agouti,
# Nearest to when: if, where, after, though, but, before, kapoor, however,
# Nearest to however: but, that, although, kapoor, when, which, and, agouti,
# Nearest to to: will, agouti, can, mitral, nine, bckgr, dasyprocta, not,
# Nearest to be: been, have, is, were, was, are, by, become,
# Nearest to he: it, she, they, who, there, exclaimed, aam, tora,
# Nearest to there: they, it, he, often, which, generally, nitride, still,
# Nearest to most: more, many, some, pools, gathered, teen, corsican, rarities,
# Nearest to if: when, although, but, venomous, will, where, costumes, cordoba,
# Average loss at step  92000 :  4.669210950016976
# Average loss at step  94000 :  4.733876184225083
# Average loss at step  96000 :  4.699397982597351
# Average loss at step  98000 :  4.587545802235604
# Average loss at step  100000 :  4.708663110494614
# Nearest to would: can, will, may, could, might, must, should, cannot,
# Nearest to zero: eight, five, nine, four, seven, six, dasyprocta, three,
# Nearest to a: the, any, thaler, kifl, michelob, agouti, dasyprocta, iit,
# Nearest to first: second, last, operatorname, next, massacre, bankruptcy, pulau, thx,
# Nearest to had: has, have, was, were, behaves, became, agouti, gollancz,
# Nearest to by: with, as, gollancz, be, was, during, dasyprocta, agouti,
# Nearest to between: with, in, from, during, annexation, criticizes, amaranthus, cliff,
# Nearest to it: he, this, there, she, which, they, tora, kifl,
# Nearest to when: if, where, after, though, but, before, kapoor, however,
# Nearest to however: but, although, that, kapoor, when, and, which, during,
# Nearest to to: will, agouti, mitral, can, bckgr, abet, dasyprocta, should,
# Nearest to be: been, have, is, were, become, was, by, being,
# Nearest to he: it, she, they, there, who, aam, exclaimed, tora,
# Nearest to there: they, it, he, often, generally, which, this, still,
# Nearest to most: more, many, some, gathered, pools, teen, corsican, rarities,
# Nearest to if: when, although, but, venomous, kapoor, where, though, cordoba,

# %%
# Step 6: Visualize the embeddings.
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

  plt.savefig(filename)

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))
