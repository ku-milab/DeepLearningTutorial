# %% [markdown]
# # Word2Vec
# Revised for SKT Deep Learning Lecture
# Originally from tensorflow.org

# %%
# !pip install tensorflow-gpu==1.13.1

import argparse
import collections
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector
# Out:
# Requirement already satisfied: tensorflow-gpu==1.13.1 in /usr/local/lib/python3.6/dist-packages (1.13.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.15.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.2.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.33.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (3.7.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.0.9)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.0.7)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.16.4)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.13.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.8.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.7.1)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.13.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.13.1) (41.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (2.8.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.1) (3.0.5)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (0.15.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.1.1)

# %%
data_index = 0

current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

log_dir = os.path.join(current_path, 'log')

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(log_dir):
  os.makedirs(log_dir)

# %%
# Step 1: Download the data.
def maybe_download(url, filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename, local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename

filename = maybe_download('http://mattmahoney.net/dc/', 'text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = {}
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = []
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, unused_dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit
# the validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal([vocabulary_size, embedding_size],
                              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all
  # embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned
    # "summary" variable. Feed metadata variable to session for visualizing
    # the graph in TensorBoard.
    _, summary, loss_val = session.run([optimizer, merged, loss],
                                       feed_dict=feed_dict,
                                       run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000
      # batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in
  # TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  282.32598876953125
# Nearest to by: withered, historicity, ebrd, bryson, premeditated, gprs, bunny, distanced,
# Nearest to who: menial, padua, diurnal, oxidizes, wet, chai, regaining, unwarranted,
# Nearest to however: purges, nipples, salic, tenochtitlan, collectivized, excitotoxins, mishneh, wally,
# Nearest to it: drone, mohair, adder, muharram, trophy, amputees, synagogues, lama,
# Nearest to when: gatherers, against, meadows, blanton, arlen, gypsies, tempos, inciting,
# Nearest to many: sangha, pannonian, colonnade, inflicted, jealous, propeller, salinger, sooner,
# Nearest to while: executing, mx, folklorist, hedonism, knots, rican, humayun, trinomial,
# Nearest to about: certificate, creationism, dilbert, partially, constriction, euphoria, tanker, amex,
# Nearest to all: compiled, nawaf, hq, hinted, atl, virtuosic, trapper, gottes,
# Nearest to have: yeshiva, edgard, diophantine, queues, coast, rushdie, wimbledon, blume,
# Nearest to th: humorously, grasslands, interface, bnetd, drops, witte, wove, disjoint,
# Nearest to years: wharton, profitable, hacking, prolonging, scramble, fascism, livingston, buchner,
# Nearest to their: mnr, flux, carom, hopeless, admits, offspring, hanja, chianti,
# Nearest to s: pompous, zondervan, upwards, comstock, luigi, pertaining, scotty, sayer,
# Nearest to up: chop, eyepiece, unconquered, att, extermination, geoff, widowed, assassins,
# Nearest to to: wattle, replied, inhibitor, scum, clues, gbit, erebus, folketing,
# Average loss at step  2000 :  113.94840124702453
# Average loss at step  4000 :  52.285455890893935
# Average loss at step  6000 :  33.36468530535698
# Average loss at step  8000 :  23.679074759125708
# Average loss at step  10000 :  17.66496311020851
# Nearest to by: and, during, in, from, kicker, as, UNK, for,
# Nearest to who: medical, not, menial, comic, wet, diurnal, responsibility, persepolis,
# Nearest to however: amo, midas, refresh, purges, cousin, geese, antimatter, and,
# Nearest to it: he, a, planck, and, justice, tissue, phi, no,
# Nearest to when: against, gatherers, urgell, ex, june, zeus, russell, time,
# Nearest to many: the, jealous, algae, information, propeller, capsule, hakama, united,
# Nearest to while: executing, ghost, hyacinthus, deaths, carbine, strassburg, affairs, nine,
# Nearest to about: partially, settle, field, force, rational, criminals, approval, french,
# Nearest to all: happens, canaris, compiled, phi, encyclopedia, able, marr, farmers,
# Nearest to have: coke, phi, wimbledon, yeshiva, coast, dddddd, edgard, canaris,
# Nearest to th: balls, humorously, nine, drops, theism, movement, eight, believing,
# Nearest to years: fascism, beyond, profitable, recollection, backs, bofors, available, victory,
# Nearest to their: the, his, botanical, princes, constructing, vote, telephone, presidential,
# Nearest to s: and, the, his, creditors, or, cardinality, UNK, zero,
# Nearest to up: wings, cheaper, extermination, unsafe, coke, profile, altenberg, exciting,
# Nearest to to: and, would, of, authors, abwehr, in, anni, into,
# Average loss at step  12000 :  14.158861815571784
# Average loss at step  14000 :  11.76817318367958
# Average loss at step  16000 :  10.053262431383134
# Average loss at step  18000 :  8.45395420229435
# Average loss at step  20000 :  8.05777120232582
# Nearest to by: in, was, from, and, during, dasyprocta, as, is,
# Nearest to who: he, not, and, medical, dasyprocta, menial, comic, wet,
# Nearest to however: friars, amo, geese, midas, purges, refresh, cousin, dasyprocta,
# Nearest to it: he, adder, this, they, dasyprocta, which, no, planck,
# Nearest to when: against, urgell, gatherers, and, russell, ex, incompleteness, lure,
# Nearest to many: jealous, the, acacia, some, information, sangha, circ, algae,
# Nearest to while: executing, ghost, and, zero, carbine, strassburg, hbox, s,
# Nearest to about: certificate, two, yin, partially, settle, five, calculation, circ,
# Nearest to all: hinted, apatosaurus, fricative, neill, canaris, happens, agouti, dasyprocta,
# Nearest to have: be, had, coke, has, wimbledon, phi, yeshiva, are,
# Nearest to th: humorously, eight, zero, balls, seven, six, four, drops,
# Nearest to years: fascism, recollection, beyond, profitable, five, backs, hacking, stilicho,
# Nearest to their: his, the, its, botanical, constructing, fricative, princes, vote,
# Nearest to s: and, zero, his, the, dasyprocta, or, of, creditors,
# Nearest to up: exciting, cheaper, UNK, specified, widowed, extermination, geoff, wings,
# Nearest to to: and, would, wattle, into, abwehr, for, from, in,
# Average loss at step  22000 :  6.970865451455117
# Average loss at step  24000 :  6.881128450274468
# Average loss at step  26000 :  6.699453935623169
# Average loss at step  28000 :  6.39837120103836
# Average loss at step  30000 :  5.888402959465981
# Nearest to by: in, with, during, was, from, chalukyas, as, and,
# Nearest to who: he, not, menial, medical, diurnal, and, dasyprocta, they,
# Nearest to however: friars, amo, excitotoxins, midas, but, geese, refresh, and,
# Nearest to it: he, this, adder, which, also, they, she, dasyprocta,
# Nearest to when: against, and, urgell, malignant, with, birkenau, in, incompleteness,
# Nearest to many: some, jealous, acacia, sangha, the, several, ubiquitous, credits,
# Nearest to while: trinomial, executing, by, is, strassburg, s, and, carbine,
# Nearest to about: certificate, settle, partially, yin, calculation, two, polarity, field,
# Nearest to all: apatosaurus, neill, hinted, agouti, fricative, happens, kj, canaris,
# Nearest to have: had, be, are, has, coke, were, diophantine, yeshiva,
# Nearest to th: seven, eight, humorously, nine, zero, balls, six, drops,
# Nearest to years: fascism, wharton, hacking, two, recollection, six, beyond, profitable,
# Nearest to their: his, its, the, devolution, fricative, birkenau, botanical, a,
# Nearest to s: and, his, zero, the, morita, two, dasyprocta, or,
# Nearest to up: cheaper, exciting, scaled, lineage, extermination, specified, affirms, geoff,
# Nearest to to: would, birkenau, wattle, will, for, abwehr, not, into,
# Average loss at step  32000 :  5.963165906846523
# Average loss at step  34000 :  5.639085829377175
# Average loss at step  36000 :  5.7765019475221635
# Average loss at step  38000 :  5.540113176107407
# Average loss at step  40000 :  5.273866821408272
# Nearest to by: was, during, in, be, from, dasyprocta, and, with,
# Nearest to who: he, not, menial, and, they, which, dasyprocta, diurnal,
# Nearest to however: but, excitotoxins, amo, friars, midas, geese, and, refresh,
# Nearest to it: he, this, she, which, they, adder, there, also,
# Nearest to when: against, urgell, and, although, but, incompleteness, that, malignant,
# Nearest to many: some, jealous, several, the, sangha, these, acacia, circ,
# Nearest to while: trinomial, and, is, by, was, executing, strassburg, zero,
# Nearest to about: certificate, settle, recitative, polarity, partially, four, yin, amex,
# Nearest to all: apatosaurus, neill, hinted, agouti, two, fricative, canaris, dasyprocta,
# Nearest to have: had, has, be, are, were, diophantine, coke, yeshiva,
# Nearest to th: eight, seven, zero, six, humorously, four, nine, drops,
# Nearest to years: fascism, wharton, six, hacking, recollection, four, beyond, backs,
# Nearest to their: his, its, the, fricative, devolution, her, a, them,
# Nearest to s: morita, and, zero, dasyprocta, the, his, emigrated, two,
# Nearest to up: cheaper, exciting, scaled, specified, patiently, extermination, affirms, lineage,
# Nearest to to: not, wattle, nine, will, birkenau, would, abwehr, can,
# Average loss at step  42000 :  5.36668147623539
# Average loss at step  44000 :  5.219371841549873
# Average loss at step  46000 :  5.226447610974311
# Average loss at step  48000 :  5.219763391375542
# Average loss at step  50000 :  5.014125067472458
# Nearest to by: was, during, be, dasyprocta, from, chalukyas, is, with,
# Nearest to who: he, and, they, not, which, menial, dasyprocta, also,
# Nearest to however: but, friars, and, amo, kapoor, midas, excitotoxins, dasyprocta,
# Nearest to it: he, this, she, which, adder, they, deuterostomes, there,
# Nearest to when: and, but, against, although, urgell, franchisee, though, if,
# Nearest to many: some, several, these, jealous, kapoor, the, two, sangha,
# Nearest to while: and, trinomial, by, is, six, for, coke, pluperfect,
# Nearest to about: certificate, settle, recitative, four, polarity, three, field, partially,
# Nearest to all: two, neill, apatosaurus, agouti, three, hinted, canaris, birkenau,
# Nearest to have: had, has, be, are, were, diophantine, coke, infancy,
# Nearest to th: eight, humorously, six, seven, nine, drops, four, zero,
# Nearest to years: wharton, fascism, recollection, hacking, six, four, three, backs,
# Nearest to their: his, its, the, her, fricative, them, devolution, finest,
# Nearest to s: and, his, zero, dasyprocta, morita, kapoor, of, trinomial,
# Nearest to up: cheaper, exciting, them, scaled, patiently, lineage, unranked, down,
# Nearest to to: will, would, can, wattle, birkenau, abwehr, agouti, into,
# Average loss at step  52000 :  5.03379484975338
# Average loss at step  54000 :  5.176835678577423
# Average loss at step  56000 :  5.06561155128479
# Average loss at step  58000 :  5.07492403948307
# Average loss at step  60000 :  4.938552653312683
# Nearest to by: was, during, be, dasyprocta, eight, chalukyas, seven, from,
# Nearest to who: he, they, which, dasyprocta, also, not, menial, that,
# Nearest to however: but, wct, michelob, kapoor, midas, amo, friars, excitotoxins,
# Nearest to it: he, this, she, which, they, there, adder, deuterostomes,
# Nearest to when: but, although, if, against, though, four, urgell, six,
# Nearest to many: some, several, these, michelob, two, kapoor, jealous, other,
# Nearest to while: wct, trinomial, although, and, is, by, but, was,
# Nearest to about: certificate, recitative, five, settle, six, four, anus, seven,
# Nearest to all: two, michelob, neill, three, microbats, many, apatosaurus, hinted,
# Nearest to have: had, has, are, were, be, diophantine, coke, infancy,
# Nearest to th: eight, six, seven, humorously, four, nine, five, zero,
# Nearest to years: wharton, fascism, recollection, six, four, hacking, backs, cen,
# Nearest to their: his, its, the, her, fricative, michelob, them, devolution,
# Nearest to s: dasyprocta, morita, kapoor, his, zero, wct, and, eight,
# Nearest to up: them, cheaper, out, exciting, patiently, scaled, down, lineage,
# Nearest to to: will, would, birkenau, not, wattle, can, nine, abwehr,
# Average loss at step  62000 :  4.983726969242096
# Average loss at step  64000 :  4.828466699659824
# Average loss at step  66000 :  4.603799107789993
# Average loss at step  68000 :  4.967926166176796
# Average loss at step  70000 :  4.9152438131570815
# Nearest to by: was, during, be, dasyprocta, with, wct, apprehended, chalukyas,
# Nearest to who: he, they, which, also, dasyprocta, menial, often, not,
# Nearest to however: but, michelob, wct, kapoor, midas, excitotoxins, since, amo,
# Nearest to it: he, this, she, which, they, there, adder, deuterostomes,
# Nearest to when: cebus, but, although, if, though, against, during, urgell,
# Nearest to many: some, several, these, all, other, michelob, kapoor, jealous,
# Nearest to while: wct, although, trinomial, and, but, when, like, or,
# Nearest to about: certificate, microcebus, recitative, settle, anus, four, polarity, only,
# Nearest to all: many, michelob, tico, apatosaurus, these, microbats, neill, hinted,
# Nearest to have: had, has, are, were, be, diophantine, coke, infancy,
# Nearest to th: six, eight, humorously, seven, three, nine, drops, four,
# Nearest to years: wharton, fascism, recollection, hacking, six, four, three, cen,
# Nearest to their: its, his, the, her, them, fricative, michelob, some,
# Nearest to s: and, dasyprocta, his, morita, zero, kapoor, upanija, wct,
# Nearest to up: them, cheaper, out, down, patiently, scaled, exciting, lineage,
# Nearest to to: will, birkenau, not, would, wattle, pettigrew, abwehr, can,
# Average loss at step  72000 :  4.767383569955826
# Average loss at step  74000 :  4.789441375255585
# Average loss at step  76000 :  4.742665724754334
# Average loss at step  78000 :  4.7909954124093055
# Average loss at step  80000 :  4.802064455330372
# Nearest to by: during, was, be, dasyprocta, wct, edt, in, with,
# Nearest to who: he, they, which, dasyprocta, also, menial, often, there,
# Nearest to however: but, michelob, wct, kapoor, since, when, agouti, refresh,
# Nearest to it: he, this, she, which, there, they, adder, microcebus,
# Nearest to when: cebus, but, if, although, though, during, while, franchisee,
# Nearest to many: some, several, these, all, most, michelob, pontificia, other,
# Nearest to while: although, wct, when, and, like, but, trinomial, rasterization,
# Nearest to about: certificate, microcebus, recitative, settle, four, anus, filmfour, only,
# Nearest to all: many, michelob, two, these, three, tico, neill, some,
# Nearest to have: had, has, were, are, be, diophantine, coke, infancy,
# Nearest to th: six, seven, humorously, eight, five, nine, drops, four,
# Nearest to years: wharton, fascism, recollection, cen, hacking, six, grievances, backs,
# Nearest to their: its, his, the, her, fricative, them, michelob, some,
# Nearest to s: dasyprocta, morita, zero, loma, kapoor, wct, five, his,
# Nearest to up: them, out, cheaper, down, patiently, exciting, lineage, scaled,
# Nearest to to: will, birkenau, would, can, not, upanija, wattle, agouti,
# Average loss at step  82000 :  4.762227478861809
# Average loss at step  84000 :  4.752874533772468
# Average loss at step  86000 :  4.758209409832954
# Average loss at step  88000 :  4.7482805542945865
# Average loss at step  90000 :  4.7224413728713985
# Nearest to by: during, was, dasyprocta, wct, from, as, trinomial, be,
# Nearest to who: he, they, which, often, dasyprocta, also, never, and,
# Nearest to however: but, michelob, wct, that, kapoor, when, while, since,
# Nearest to it: he, this, she, there, which, they, deuterostomes, adder,
# Nearest to when: if, although, while, but, cebus, after, during, though,
# Nearest to many: some, several, these, all, most, pontificia, michelob, various,
# Nearest to while: although, when, wct, and, but, however, if, like,
# Nearest to about: certificate, microcebus, recitative, settle, only, anus, three, filmfour,
# Nearest to all: many, michelob, these, some, two, tico, hinted, agouti,
# Nearest to have: had, has, were, are, be, diophantine, coke, infancy,
# Nearest to th: six, eight, nine, seven, humorously, three, five, drops,
# Nearest to years: wharton, recollection, fascism, cen, three, hacking, days, grievances,
# Nearest to their: its, his, the, her, fricative, michelob, them, some,
# Nearest to s: and, dasyprocta, morita, kapoor, wct, upanija, was, integrate,
# Nearest to up: them, out, down, cheaper, patiently, exciting, lineage, scaled,
# Nearest to to: will, birkenau, would, wattle, agouti, pettigrew, abwehr, not,
# Average loss at step  92000 :  4.665378226280213
# Average loss at step  94000 :  4.727893386244774
# Average loss at step  96000 :  4.701432646512985
# Average loss at step  98000 :  4.595462461411953
# Average loss at step  100000 :  4.694656722068786
# Nearest to by: during, was, wct, dasyprocta, chalukyas, as, be, trinomial,
# Nearest to who: he, they, also, dasyprocta, often, never, which, and,
# Nearest to however: but, michelob, and, that, wct, since, while, when,
# Nearest to it: he, this, she, there, they, which, adder, deuterostomes,
# Nearest to when: if, while, although, cebus, after, during, before, though,
# Nearest to many: some, several, these, all, various, most, michelob, pontificia,
# Nearest to while: when, although, but, wct, if, however, and, like,
# Nearest to about: certificate, microcebus, recitative, three, tba, only, settle, anus,
# Nearest to all: many, some, these, michelob, both, tico, two, hinted,
# Nearest to have: had, has, were, are, be, diophantine, coke, dddddd,
# Nearest to th: nine, six, seven, humorously, drops, eight, sixties, five,
# Nearest to years: wharton, recollection, fascism, days, cen, prima, grievances, det,
# Nearest to their: its, his, her, the, fricative, some, michelob, these,
# Nearest to s: dasyprocta, kapoor, morita, loma, and, mitral, wct, his,
# Nearest to up: out, them, down, cheaper, patiently, scaled, lineage, exciting,
# Nearest to to: will, tba, birkenau, agouti, wattle, abwehr, pettigrew, must,

# %%
# Step 6: Visualize the embeddings.
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

  plt.savefig(filename)

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))
